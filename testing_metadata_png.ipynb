# %% [markdown]
# # Stamping test image

# %%
import matplotlib.pyplot as plt
from stampfig import stamp_fig, get_data

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
fig, ax = plt.subplots()
ax.scatter([1,2,3], [4,5,6])
ax.set_title('A scatter plot')
ax.set_xlabel('X')
ax.set_xlabel('Y')

fig.savefig('test_image.png')

# %%
stamp_fig('test_image.png', __vsc_ipynb_file__)

# %%
get_data("test_image.png")
# Out:
# {'plot_from_file': '/Users/ssagear/Dropbox (UFL)/CCA/MDwarfProperties/FinalDataAnalysis/stampfig/testing_metadata_png.ipynb',
#  'date_created': '2023-10-31 17:12:38.144048'}
